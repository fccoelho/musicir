# %% [markdown]
# # Creating and visualizing Rhythms
# In this notebook we will explore the generation and visualizations of rhythm patterns on a circle.

# %%
from musicir.rhythm.generate import Euclid, RhythmViewer
# %matplotlib inline

# %% [markdown]
# The Cuban Tresillo, the first bar of the "Son clave" can be define as a `E(3,8)`

# %%
E= Euclid(3,8)
E
# Out:
# X..X..X.

# %%
E.beat.show()

# %%
R = RhythmViewer(E.rhythm)
R.show()

# %% [markdown]
# Let's hear it. By default  the play method plays it twice.

# %%
E.play()
# Out:
#                 <div id='midiPlayerDiv620'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv620');
#                                mp.base64Load('...');
#                         });
#                 </script>

# %% [markdown]
# To listen to more repetitions, we can use the `get_beat` to generate the stream with as many repetitions as we wish.

# %%
st = E.get_beat(times=5)
st.show('midi')
# Out:
#                 <div id='midiPlayerDiv924'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv924');
#                                mp.base64Load('...');
#                         });
#                 </script>

# %% [markdown]
# The Quintillo is another well known Cuban rhythm.

# %%
E = Euclid(5, 8)
E
# Out:
# X.XX.XX.

# %%
R = RhythmViewer(E.rhythm)
R.show()

# %%
E.play()
# Out:
#                 <div id='midiPlayerDiv1096'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv1096');
#                                mp.base64Load('...');
#                         });
#                 </script>

# %%
beat = E.get_beat(times=5)
beat.show('midi')
# Out:
#                 <div id='midiPlayerDiv1400'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv1400');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
beat.show()

# %%
from musicir.rhythm.generate import traditional_rhythms

# %%
ES = traditional_rhythms['samba']

# %%
samba = ES.get_beat(times=3)
samba.show('midi')
# Out:
#                 <div id='midiPlayerDiv1862'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv1862');
#                                mp.base64Load('...');
#                         });
#                 </script>

# %%
RS = RhythmViewer(ES.rhythm)
RS.show()
