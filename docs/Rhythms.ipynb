# %% [markdown]
# # Creating and visualizing Rhythms
# In this notebook we will explore the generation and visualizations of rhythm patterns on a circle.

# %%
from musicir.rhythm.generate import Euclid, RhythmViewer
# %matplotlib inline

# %% [markdown]
# The Cuban Tresillo, the first bar of the "Son clave" can be define as a `E(3,8)`

# %%
E= Euclid(3,8)
E
# Out:
# X..X..X.

# %%
E.beat.show()

# %%
R = RhythmViewer(E.rhythm)
R.show()

# %% [markdown]
# Let's hear it. By default  the play method plays it twice.

# %%
E.play()
# Out:
#                 <div id='midiPlayerDiv244'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv244');
#                                mp.base64Load('...');
#                         });
#                 </script>

# %% [markdown]
# To listen to more repetitions, we can use the `get_beat` to generate the stream with as many repetitions as we wish.

# %%
st = E.get_beat(times=5)
st.show('midi')
# Out:
#                 <div id='midiPlayerDiv548'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv548');
#                                mp.base64Load('...');
#                         });
#                 </script>

# %% [markdown]
# The Quintillo is another well known Cuban rhythm.

# %%
E = Euclid(5, 8)
E
# Out:
# X.XX.XX.

# %%
R = RhythmViewer(E.rhythm)
R.show()

# %%
E.play()
# Out:
#                 <div id='midiPlayerDiv902'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv902');
#                                mp.base64Load('...');
#                         });
#                 </script>

# %%
beat = E.get_beat(times=5)
beat.show('midi')
# Out:
#                 <div id='midiPlayerDiv1290'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv1290');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
beat.show()
